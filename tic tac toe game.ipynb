# %%
print("WELCOME TO TIC TAC TOE GAME\n PLAYER-1 WILL BE X \n PLAYER-2 WILL BE O")
lst=[' ']*10
print("Your Board looks like this!! ")
print(lst[1], '1' + '|', lst[2], '2' + '|', lst[3], '3' + '|')
print("---------")
print(lst[4], '4' + '|', lst[5], '5' + '|', lst[6], '6' + '|')
print("---------")
print(lst[7], '7' + '|', lst[8], '8' + '|', lst[9], '9' + '|')
def gameboard():
    print(lst[1] + '|', lst[2] + '|',lst[3] +'|')
    print("---------")
    print(lst[4] + '|', lst[5] + '|', lst[6]+ '|')
    print("---------")
    print(lst[7] + '|', lst[8] + '|', lst[9]+ '|')
gameboard()



def totalmoves():
    if j==9:
        print("the boxes are full")
        exit(1)




def winner():
    for i in range(1,4):
        if lst[i] == lst[i + 3] == lst[i + 6] == 'x' or lst[i] == lst[i + 3] == lst[i + 6] == 'o':
            if lst[i] == lst[i + 3] == lst[i + 6] == 'x':
                print("player1 You WON!! 1 ")
                exit(1)

            else:
                print("player2 You WON!! 2")
                exit(1)

        for k in range(1,8,3):
            if lst[k] == lst[k + 1] == lst[k + 2] == 'x' or lst[k] == lst[k + 1] == lst[k + 2] == 'o':
                if lst[k] == lst[k + 1] == lst[k + 2] == 'x':
                     print("player1 You WON!! 3")
                     exit(1)
                else:
                     print("player2 You WON!! 4")
                     exit(1)
            for l in range(4,6):
                   if l==5 and (lst[l]==lst[l-2]==lst[l+2]=='x' or lst[l]==lst[l-2]==lst[l+2]=='o'):
                       if lst[l]==lst[l-2]==lst[l+2]=='x':
                        print("player1 You WON!! 5")
                        exit(1)
                       else:
                           print("PLAYER2 You WON!! 6")
                           exit(1)
                   elif l==5 and (lst[l]==lst[l-4]==lst[l+4]=='x' or lst[l]==lst[l-4]==lst[l+4]=='o'):
                       if lst[l]==lst[l-4]==lst[l+4]=='x':
                           print("player1 You WON!! 7")
                           exit(1)
                       else:
                           print("player2 You WON!! 8")
                           exit(1)






j=1
while j<10:
        L1=int(input("play player1!!!\n"))
        if L1== 0:
            print("invaild Box Number!!")
            continue
        if lst[L1] == ' ':
          lst[L1]='x'
          gameboard()
          winner()
          totalmoves()
          j += 1

        else:
            print("invalid (*_*) ")
            continue
        L2= int(input("play player2!!!\n"))
        if L2== 0:
            print("invaild Box Number!!")
        if lst[L2] == ' ':
            lst[L2] = 'o'
            gameboard()
            winner()
            j += 1
        else:
            print("invalid *_* ")
            continue
